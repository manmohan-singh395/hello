# %%
#  dictionary

student =  {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
}
# print(student["age"])
# print(student["name"])

for i in student:
    print(i  , ": " , student[i])
# Out:
# name :  manmohan
# age :  23
# is_active :  True
# city :  Delhi

# %%
students = {"stu1":{
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
},
"stu2" : {
    "name":"aman",
    "age":22,
    "is_active":True,
    "city":"Delhi"
},
"stu3":{
    "name":"himanshi",
    "age":"21",
    "is_active":"True",
    "city":"Delhi"
}}

for i in students:
 name = students[i]["name"]
 age = students[i]["age"]
 print(name, ":" , age)
# Out:
# manmohan : 23
# aman : 22
# himanshi : 21

# %%
stu =  {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
}
print(stu)
print(stu.keys())
print(stu.values())
print(stu.items())
print(stu.get("name"))
stu.update({"name":"aman"})
print(stu.get("name"))
# Out:
# {'name': 'manmohan', 'age': 23, 'is_active': True, 'city': 'Delhi'}
# dict_keys(['name', 'age', 'is_active', 'city'])
# dict_values(['manmohan', 23, True, 'Delhi'])
# dict_items([('name', 'manmohan'), ('age', 23), ('is_active', True), ('city', 'Delhi')])
# manmohan
# aman
