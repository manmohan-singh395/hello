# %%
def student_profile(name,*skills , **details):
    print(f"Student Name: {name} ,  skills: {skills} , details: {details}")

student_profile("Man Mohan" ,  "Python" , "React" ,  "Node" , city="Delhi" , state="Delhi" , country="India" , pincode=110091)
# Out:
# Student Name: Man Mohan ,  skills: ('Python', 'React', 'Node') , details: {'city': 'Delhi', 'state': 'Delhi', 'country': 'India', 'pincode': 110091}

# %%
def add(a,b):return a+b
print(add(1,2))


# add_lambda  = lambda a,b : a+b
# print(add_lambda(1,2))
# Out:
# 3

# %%
# # math 
# random 
# datetime

import math 
import random
from datetime import datetime

print(math.sqrt(12))
print(random.randint(1,10))
print(datetime.now())
# Out:
# 3.4641016151377544
# 6
# 2026-04-13 17:05:16.312638

# %%
import helper
helper.message("Man mohan")
# Out:
# welcome to 4 achievers

# %%
trainer = "ganesh dutt"

def my_class():
    topic = "pyton"
    print(f"{trainer} is teaching {topic}")

my_class()
print(trainer)
# Out:
# ganesh dutt is teaching pyton
# ganesh dutt
