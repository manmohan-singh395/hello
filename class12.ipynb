# %%
#.... number guess game.....


# import random

# secret_num = random.randint(1,20)
# attempts = 0
# max_attempts = 5
# guess = 0

# while guess != secret_num and attempts < max_attempts:
#     guess = int(input("guess the number between 1 and 20:"))
#     attempts += 1

#     if guess< secret_num:
#         print("too low1")
#     elif guess> secret_num:
#         print("too high!")
#     else:
#         print(f"congractulation! you have guessed the number in {attempts} attempts.")


# .....password generator....

# import random
# length = int(input("enter the desired number:"))
# char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
# password = ""

# for i in range(length):
#     random_char = random.choice(char)
#     password += random_char

# print(password)

# ....fizz buzz game.....
# for i in range(1,51):
#     if i%3 and i%5 == 0:
#         print("fizzbuzz")
#     elif i%3 == 0:
#         print("fizz")
#     elif i%5 == 0:
#         print("buzz")
#     else:
#         print(i)
# Out:
# too low1
# too low1
# too high!
# too low1
# congractulation! you have guessed the number in 5 attempts.
