# %%
# for i in range(1,16):
#     print(i)

# %%
# i = 2
# while i<=5:
#     print(i)
#     i += 2

# %%
# num = int(input("enter a number: "))

# for i in range(1,11):
#     print(num,"*",i,"=",num * i)

# %%
# n = int(input("enter a number :"))
# sum = 0
# for i in range(1,n+1):
#     sum += 1
# print(sum)

# %%
num = 1234
rev = 0
for i in range(len)
# Out:
#   Cell In[5], line 3
#     for i in range(len)
#                        ^
# SyntaxError: expected ':'
